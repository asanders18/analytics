# %%
# imports

import pandas
import re
import nltk
import collections
import datetime

# %%
df=pandas.read_csv("https://raw.githubusercontent.com/asanders18/analytics/master/data/example.csv") # can also read locally

# %%
df.head(10)
# Out:
#                                     URL            Keyword  Search Volume  \
# 0  https://www.example.com/shape/square         four sides            634
# 1  https://www.example.com/shape/circle              round            598
# 2    https://www.example.com/color/blue           sky blue            850
# 3    https://www.example.com/color/blue          navy blue            496
# 4    https://www.example.com/color/blue               blue            260
# 5   https://www.example.com/color/green            verdant            237
# 6         https://www.example.com/color  colors of rainbow            444
# 7    https://www.example.com/color/blue          blue eyes            440
# 8    https://www.example.com/color/blue       classic blue            741
# 9  https://www.example.com/color/purple             violet            116
#
#    Rank
# 0     5
# 1     2
# 2     3
# 3     5
# 4     8
# 5     3
# 6     1
# 7     9
# 8     9
# 9     4

# %%
# Site sections overview

def isSiteSection(url):
    if "https://www.example.com/" == url:
        return "Homepage"   
    elif "/color" in url:
        return "Colors"    
    elif "/shape" in url:
        return "Shapes"
    else: 
        return "Null"
    

#Iterate through the df by URL
df["Sections"]=df["URL"].apply(lambda x: isSiteSection(x))

# Checking our data (printing first 5 rows)
df.head(5)
# Out:
#                                     URL     Keyword  Search Volume  Rank  \
# 0  https://www.example.com/shape/square  four sides            634     5
# 1  https://www.example.com/shape/circle       round            598     2
# 2    https://www.example.com/color/blue    sky blue            850     3
# 3    https://www.example.com/color/blue   navy blue            496     5
# 4    https://www.example.com/color/blue        blue            260     8
#
#   Sections
# 0   Shapes
# 1   Shapes
# 2   Colors
# 3   Colors
# 4   Colors

# %%
# if you want to use regex

df["Blue"] = site["URL"].apply(lambda x : re.findall(r'\/blue', x)) # can use regex

# print all of df
df
# Out:
#                                      URL            Keyword  Search Volume  \
# 0   https://www.example.com/shape/square         four sides            634
# 1   https://www.example.com/shape/circle              round            598
# 2     https://www.example.com/color/blue           sky blue            850
# 3     https://www.example.com/color/blue          navy blue            496
# 4     https://www.example.com/color/blue               blue            260
# 5    https://www.example.com/color/green            verdant            237
# 6          https://www.example.com/color  colors of rainbow            444
# 7     https://www.example.com/color/blue          blue eyes            440
# 8     https://www.example.com/color/blue       classic blue            741
# 9   https://www.example.com/color/purple             violet            116
# 10   https://www.example.com/color/black               noir            921
# ...

# %%
# print to .csv called "categorized_colors.csv"
df.to_csv(r"categorized_colors.csv")

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# <br><br><br><br><br><br><br>
